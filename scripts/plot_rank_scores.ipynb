# %% [markdown]
# <h3>Plotting for Storage formats</h3>

# %%
#storage formats
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as font_manager

path = "C:\\Users\\Sadiq\\Desktop\\p"
schemas = ['ST', 'VT', 'PT']
partitionings = ['HP', 'SBP', 'PBP']
formats = [ 'ORC', 'PARQUET', 'HIVE', 'AVRO', 'CSV']
sizes = ['100M', '500M']
df = []

# 100M ST
df.append([0.82, 0.93, 0.98])
df.append([0.64, 0.66, 0.45])
df.append([0.77, 0.68, 0.43])
df.append([0.27, 0.25, 0.59])
df.append([0.00, 0.00, 0.05])

# 100M VT
df.append([0.77, 0.57, 0.39])
df.append([0.70, 0.75, 0.57])
df.append([0.52, 0.61, 0.25])
df.append([0.30, 0.39, 0.73])
df.append([0.23, 0.20, 0.57])

# 100M PT
df.append([0.55, 0.70, 0.45])
df.append([0.68, 0.61, 0.23])
df.append([0.36, 0.39, 0.25])
df.append([0.34, 0.23, 0.70])
df.append([0.11, 0.11, 0.41])


# 500M ST
df.append([0.77, 1.00, 0.95])
df.append([0.59, 0.59, 0.59])
df.append([0.73, 0.61, 0.64])
df.append([0.41, 0.30, 0.32])
df.append([0.00, 0.00, 0.00])

# 500M VT
df.append([0.80, 0.80, 0.80])
df.append([0.82, 0.75, 0.75])
df.append([0.55, 0.57, 0.23])
df.append([0.27, 0.32, 0.64])
df.append([0.07, 0.07, 0.09])

# 500M PT
df.append([0.64, 0.64, 0.59])
df.append([0.55, 0.66, 0.36])
df.append([0.39, 0.39, 0.36])
df.append([0.32, 0.25, 0.61])
df.append([0.16, 0.11, 0.11])

colors = [ 'burlywood', 'salmon',  'dodgerblue', 'dimgray', 'darkgreen']
width = 0.1  # the width of the bars
xs = []                      
xs.append(np.arange(len(partitionings)))                                      
xs.append([x + width for x in xs[0]])
xs.append([x + width for x in xs[1]])
xs.append([x + width for x in xs[2]])
xs.append([x + width for x in xs[3]])


for s in range(len(sizes)):    
    for i in range (len(schemas)):

        fig, ax = plt.subplots(figsize=(6,4))                 
        for j in range(5):
            rects = ax.bar(xs[j], df[j+5*i+s*len(formats)*len(partitionings)], width, label=formats[j], color = colors[j])                
    
        ax.set_ylabel('Rank Score', fontname="Arial", fontsize=14, weight='bold')        
        ax.set_title('Rank Score - ' + schemas[i]  + ' schema (' + sizes[s] + ')', fontsize=14)
        ax.set_xticks(x)
        ax.set_xticklabels(partitionings, fontname="Arial", fontsize=14)
                
        font = font_manager.FontProperties(family='Candara', weight='bold', style='normal', size=10)
        ax.legend(bbox_to_anchor=(0.985, -0.2), ncol=len(formats), prop=font) 
        fig.tight_layout()
        
        plt.axis([-0.2, 2.7, 0, 1])
        plt.savefig(path + '\\'+sizes[s]+'\\'+'StorageFormats_'+sizes[s]+'_'+schemas[i]+ '.png', bbox_inches='tight')
        plt.show()

# %% [markdown]
# <h3>Plotting for Partitionig scores</h3>

# %%
# Partitionig scores, 1st option
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as font_manager

path = "C:\\Users\\Sadiq\\Desktop\\p" 
schemas = ['ST', 'VT', 'PT']
partitionings = ['S B P', 'H P', 'P B P']
formats = ['AVRO', 'CSV', 'ORC', 'PARQUET', 'HIVE']
sizes = ['100M', '500M']
df = []

#100M ST
df.append([0.86, 0.68, 0.95, 0.95, 0.95])
df.append([0.45, 0.23, 0.32, 0.55, 0.55])
df.append([0.18, 0.59, 0.23, 0.00, 0.00])
#100M VT
df.append([0.86, 0.59, 0.73, 0.77, 0.91])
df.append([0.36, 0.55, 0.59, 0.59, 0.55])
df.append([0.27, 0.41, 0.18, 0.14, 0.05])
#100M PT
df.append([0.59, 0.77, 0.68, 0.68, 0.68])
df.append([0.73, 0.41, 0.45, 0.45, 0.45])
df.append([0.18, 0.05, 0.09, 0.09, 0.09])


#500M ST
df.append([0.55, 0.64, 0.73, 0.59, 0.64])
df.append([0.68, 0.05, 0.18, 0.41, 0.36])
df.append([0.27, 0.82, 0.59, 0.50, 0.50])
#500M VT
df.append([0.59, 0.55, 0.59, 0.77, 0.91])
df.append([0.18, 0.36, 0.32, 0.18, 0.55])
df.append([0.73, 0.59, 0.59, 0.55, 0.05])
#500M PT
df.append([0.73, 0.73, 0.77, 0.77, 0.73])
df.append([0.45, 0.41, 0.41, 0.32, 0.36])
df.append([0.05, 0.09, 0.05, 0.14, 0.14])


# colors = ['lime', 'green', 'darkgreen']
colors = [ 'salmon',  'dodgerblue', 'darkgreen']
width = 0.2

xs = []                      
xs.append(np.arange(len(formats)))                                      
xs.append([x + width for x in xs[0]])
xs.append([x + width for x in xs[1]])

for s in range(len(sizes)):    
    for i in range (len(schemas)):

        fig, ax = plt.subplots(figsize=(6, 4))                        
        for j in range(3):
            rects = ax.bar(xs[j], df[j+3*i+s*len(schemas)*len(partitionings)], width, label=partitionings[j], color = colors[j])        

        ax.set_ylabel('Rank Score', fontname="Arial", fontsize=14, weight='bold')
        ax.set_title('Rank Score - ' + schemas[i]  + ' schema (' + sizes[s] + ')', fontsize=14)
        ax.set_xticks(x)
        ax.set_xticklabels(formats, fontname="Arial", fontsize=14)
    
        font = font_manager.FontProperties(family='Candara', weight='bold',style='normal', size=14)
        ax.legend(bbox_to_anchor=(0.85, -0.2), ncol=len(formats), prop=font) #prop={'size': 8} 
        fig.tight_layout()
        plt.axis([-0.3, 4.7, 0, 1])
        plt.savefig(path + '\\'+sizes[s]+'\\'+'Partitioning_'+ sizes[s] + '_' + schemas[i] + '.png', bbox_inches='tight')
        plt.show()

# %% [markdown]
# <h3>Plotting for Relational schemas</h3>

# %%
# Partitionig scores, 1st option
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as font_manager

path = "C:\\Users\\Sadiq\\Desktop\\p" 
# schemas = ['ST', 'VT', 'PT']
schemas = ['VT', 'PT', 'ST']
partitionings = ['HP', 'SBP', 'PBP']
formats = ['AVRO', 'CSV', 'ORC', 'PARQUET', 'HIVE']
sizes = ['100M', '500M']
df = []

#100M HP
df.append([0.73, 0.77, 0.68, 0.68, 0.64])
df.append([0.55, 0.64, 0.55, 0.50, 0.50])
df.append([0.23, 0.09, 0.27, 0.32, 0.36])
# 0.67, 0.78, 0.67, 0.61, 0.61

#100M SBP
df.append([0.73, 0.77, 0.68, 0.73, 0.68])
df.append([0.59, 0.64, 0.45, 0.50, 0.45])
df.append([0.18, 0.09, 0.36, 0.27, 0.36])
# 0.72, 0.78, 0.56, 0.61, 0.56

#100M PBP
df.append([0.86, 0.91, 0.77, 0.86, 0.82])
df.append([0.32, 0.41, 0.18, 0.23, 0.23])
df.append([0.32, 0.18, 0.55, 0.41, 0.45])
# 0.39, 0.50, 0.22, 0.28, 0.28

#500M HP
df.append([0.86, 0.82, 0.73, 0.82, 0.86])
df.append([0.50, 0.55, 0.55, 0.41, 0.36])
df.append([0.14, 0.14, 0.23, 0.27, 0.27])
# 0.61, 0.67, 0.67, 0.50, 0.44

#500M SBP
df.append([0.82, 0.82, 0.73, 0.77, 0.77])
df.append([0.55, 0.55, 0.41, 0.55, 0.41])
df.append([0.14, 0.14, 0.36, 0.18, 0.32])
# 0.67, 0.67, 0.50, 0.67, 0.50

#500M PBP
df.append([0.95, 0.95, 0.91, 0.95, 0.82])
df.append([0.32, 0.36, 0.14, 0.14, 0.14])
df.append([0.23, 0.18, 0.45, 0.41, 0.55])
# 0.39, 0.44, 0.17, 0.17, 0.17

colors = [ 'salmon',  'dodgerblue', 'darkgreen']
width = 0.2

xs = []                      
xs.append(np.arange(len(formats)))                                      
xs.append([x + width for x in xs[0]])
xs.append([x + width for x in xs[1]])

for s in range(len(sizes)):    
    for i in range (len(schemas)):

        fig, ax = plt.subplots(figsize=(6, 4))  
        for j in range(3):
            rects = ax.bar(xs[j], df[j+3*i+s*len(schemas)*len(partitionings)], width, label=schemas[j], color = colors[j])        

        ax.set_ylabel('Rank Score', fontname="Arial", fontsize=14, weight='bold')
        ax.set_title('Rank Score - ' + partitionings[i]  + ' (' + sizes[s] + ')', fontsize=14)
        ax.set_xticks(x)
        ax.set_xticklabels(formats, fontname="Arial", fontsize=14)
    
        font = font_manager.FontProperties(family='Candara', weight='bold',style='normal', size=14)
        ax.legend(bbox_to_anchor=(0.85, -0.2), ncol=len(formats), prop=font) #prop={'size': 8} 
        fig.tight_layout()
        
        plt.axis([-0.3, 4.7, 0, 1])
        plt.savefig(path + '\\'+sizes[s]+'\\'+'Schema_'+ sizes[s] + '_' + partitionings[i] + '.png', bbox_inches='tight')
        plt.show()
